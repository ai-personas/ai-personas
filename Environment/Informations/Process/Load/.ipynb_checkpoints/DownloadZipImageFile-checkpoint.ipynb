# %%
import sys
import imp
import os
import numpy as np
import zipfile
import requests
import StringIO
from PIL import Image

INFORMATION_BLUEPRINT = "informationBlueprint"
INFORMATION_NAME = "scientists"
INFORMATION_CATEGORY = ["Category", "Portraits"]

def getInformationBlueprint():
    #information blueprint path
    information_blueprint_path = os.path.join("..", "..")
    information_blueprint_path = os.path.abspath(os.path.join(information_blueprint_path, INFORMATION_BLUEPRINT + '_pb2.py'))
    print (information_blueprint_path)
    #import information blueprint
    informationBlueprint = imp.load_source('Information', information_blueprint_path).Information()
    return informationBlueprint

def loadInformationDefinition(informationBluePrint):
    #load information
    information_path = os.path.join("..", "..")
    for category in INFORMATION_CATEGORY:
        information_path = os.path.join(information_path, category)
    information_path = os.path.abspath(os.path.join(information_path, INFORMATION_NAME + ".bin"))
    f = open(information_path, "rb")
    informationBluePrint.ParseFromString(f.read())
    f.close()
    return informationBluePrint

class Loader(object):

    def __init__(self, loader):
        self.processor = processor
    
    # get data 
    def getData(self):
        imgArrayData = np.array([[[[]]]])
        downloadURL = self.processor.downloadZipImageFile.downloadURL
        directoryName = self.processor.downloadZipImageFile.directoryName
        print (downloadURL)
        print (directoryName)
        
#         u = requests.get(downloadURL)
#         f = StringIO.StringIO() 
#         f.write(u.content)
            
        input_zip = zipfile.ZipFile(downloadURL)
        for fileName in input_zip.namelist():
            if (directoryName+"/") in fileName:
                try:
                    print fileName
                    imgFile = input_zip.open(fileName)
                    img = Image.open(imgFile)
                    img = np.asarray(img, dtype=np.float32)
#                     imgData[0] = img
#                     print imgData.shape
                    print img.shape

                    np.vstack([imgArrayData, img])
                    print img.size
                except:
                    pass
        print (imgArrayData.shape)
        return

information = loadInformationDefinition(getInformationBlueprint())

LOADER_DOWNLOAD_ZIP_IMAGE_FILE = "downloadZipImageFile"

for processor in information.processors:
    print (processor.WhichOneof("Loader"))
    if LOADER_DOWNLOAD_ZIP_IMAGE_FILE == processor.WhichOneof("Loader"):
        print "zip image file"
        loader = Loader(processor);
        loader.getData();
# Out:
# C:\Users\rames\Documents\GitHub\ai-personas\Environment\Informations\informationBlueprint_pb2.py
# downloadZipImageFile
# zip image file
# C:\Users\rames\Downloads\portraits.zip
# scientists
# portraits/scientists/
# portraits/scientists/2Q== (1).jpg
# 75600
# portraits/scientists/2Q== (2).jpg
# 150975
# portraits/scientists/2Q== (3).jpg
# 151500
# portraits/scientists/2Q==.jpg
# 150732
# portraits/scientists/9k= (1).jpg
# 151320
# portraits/scientists/9k= (2).jpg
# 151296
# portraits/scientists/9k= (3).jpg
# 150975
# portraits/scientists/9k= (4).jpg
# 150930
# portraits/scientists/9k= (5).jpg
# 151290
# portraits/scientists/9k= (6).jpg
# 150975
# portraits/scientists/9k= (7).jpg
# 120000
# portraits/scientists/9k=.jpg
# 151524
# portraits/scientists/images (1).jpg
# 150705
# portraits/scientists/images (10).jpg
# 150738
# portraits/scientists/images (100).jpg
# 151218
# portraits/scientists/images (11).jpg
# 151032
# portraits/scientists/images (12).jpg
# 150822
# portraits/scientists/images (13).jpg
# 151041
# portraits/scientists/images (14).jpg
# 139872
# portraits/scientists/images (15).jpg
# 151248
# portraits/scientists/images (16).jpg
# 150930
# portraits/scientists/images (17).jpg
# 93600
# portraits/scientists/images (18).jpg
# 151200
# portraits/scientists/images (19).jpg
# 150822
# portraits/scientists/images (2).jpg
# 151389
# portraits/scientists/images (20).jpg
# 151320
# portraits/scientists/images (21).jpg
# 151218
# portraits/scientists/images (22).jpg
# 150975
# portraits/scientists/images (23).jpg
# 151353
# portraits/scientists/images (24).jpg
# 151335
# portraits/scientists/images (25).jpg
# 150960
# portraits/scientists/images (26).jpg
# 151164
# portraits/scientists/images (27).jpg
# 96000
# portraits/scientists/images (28).jpg
# 151188
# portraits/scientists/images (29).jpg
# 150954
